# %%
import stickytape

# %%
# !stickytape submission.py > submission_test.py

# %%
# !kaggle competitions submit -c rock-paper-scissors -f submission_merged.py -m "Message"
# Out:
# ...
# 403 - Your team has used its submission allowance (5 of 5). This resets at midnight UTC (2.6 hours from now).
#   0%|          | 0.00/60.9k [00:00<?, ?B/s]
#  13%|█▎        | 8.00k/60.9k [00:00<00:00, 81.5kB/s]
# 100%|██████████| 60.9k/60.9k [00:00<00:00, 80.9kB/s]
