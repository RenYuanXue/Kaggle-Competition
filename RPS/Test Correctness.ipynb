# %%
# %load_ext autoreload
# %autoreload 2
import submissionTest

# %%
# Write two classes, observation and configuration, in order for the script to run.
import random

class Observation:
    def __init__(self, step):
        self.step = step
        self.lastOpponentAction = random.randrange(3)

class Configuration:
    def __init__(self):
        self.episodeSteps = 1000
        self.signs = 3

# %%
# Test script.
for n in range(100):
    submissionTest.main(Observation(n), Configuration())
# Out:
# 2
# <class 'int'>
# 0
# <class 'int'>
# 2
# <class 'int'>
# 1
# <class 'int'>
# 0
# <class 'int'>
# 0
# <class 'int'>
# 2
# <class 'int'>
# 1
# <class 'int'>
# 0
# <class 'int'>
# 1
# <class 'int'>
# 1
# <class 'int'>
# 0
# <class 'int'>
# 0
# <class 'int'>
# 1
# <class 'int'>
# 2
# <class 'int'>
# 2
# <class 'int'>
# 0
# <class 'int'>
# 2
# <class 'int'>
# 2
# <class 'int'>
# 0
# <class 'int'>
# 1
# <class 'int'>
# 0
# <class 'int'>
# 1
# <class 'int'>
# 1
# <class 'int'>
# 1
# <class 'int'>
# 2
# <class 'int'>
# 0
# <class 'int'>
# 2
# <class 'int'>
# 2
# <class 'int'>
# 1
# <class 'int'>
# 0
# <class 'int'>
# 2
# <class 'int'>
# 0
# <class 'int'>
# 1
# <class 'int'>
# 0
# <class 'int'>
# 1
# <class 'int'>
# 1
# <class 'int'>
# 2
# <class 'int'>
# 0
# <class 'int'>
# 0
# <class 'int'>
# 2
# <class 'int'>
# 2
# <class 'int'>
# 0
# <class 'int'>
# 1
# <class 'int'>
# 0
# <class 'int'>
# 1
# <class 'int'>
# 1
# <class 'int'>
# 2
# <class 'int'>
# 0
# <class 'int'>
# 1
# <class 'int'>
# ...
